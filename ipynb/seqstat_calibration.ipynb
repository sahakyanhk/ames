# %%
import os, sys
import numpy as np
from matplotlib import pyplot as plt
src = os.path.dirname(os.path.abspath("../src"))

if src not in sys.path:
    sys.path.append(src)

from src.seqtools import Seqstat

# %%
rna_fasta = "/fdb/alphafold3/rnacentral_active_seq_id_90_cov_80_linclust.fasta"
rna_stat = "../data/rnacentral90_stat.json"

prot_fasta = "../pf80_rep_seq.fasta"
prot_stat = "../data/pfam80.json"

# %%
# seqtools = Seqstat(seqtype = 'rna')
# seqtools.calculate_background_distribution(rna_fasta)
# seqtools.save_background_distribution(rna_stat)
# Out:
# data/prot_stat.json does not exist. Run calculate_background_distribution or provide valid JSON.
# Parsing sequences...
# Processed 15600000 sequences...
# Processed 15630712 sequences.
# Filtering invalid k-mers...

# %%
# seqtools = Seqstat(seqtype = 'protein')
# seqtools.calculate_background_distribution(prot_fasta)
# seqtools.save_background_distribution(prot_stat)
# Out:
# No statistics file provided.
#                   Please run calculate_background_distribution to generate statistics from a FASTA file or load statistics for a json.
# Parsing sequences...
# Processed 28900000 sequences...
# Processed 28951507 sequences.
# Filtering invalid k-mers...

# %%
seqtools  = Seqstat(stat_from = prot_stat, seqtype = 'protein')
seqtools.n_gram_prior("AAAAAAAA")
# Out:
# Loading statistics from ../data/pfam80.json
# 13.319
